# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import pandas as pd
from scipy.stats import pearsonr
from sklearn.preprocessing import LabelEncoder

# %%
data= pd.read_csv("./Beverages.csv")

# %%
data.head()
# Out:
#                Name           Age  TEA_consumption  Coffee_consumption  \
# 0           Yagnesh  below 20 yrs                1                   0
# 1  Omikumar Makadia   20 - 30 yrs                2                   3
# 2      Devyash Shah   20 - 30 yrs                0                   2
# 3          Om Shah   below 20 yrs                2                   2
# 4      Sarthak dave   20 - 30 yrs                3                   3
#
#    EnergyDrinks_consumption  SoftDrinks_consumption  Milk_consumption  \
# 0                         0                       0                 1
# 1                         0                       1                 1
# 2                         0                       1                 0
# 3                         0                       0                 1
# 4                         1                       1                 1
#
#    Juices_consumption                                TEA_sleepingPattern  \
# 0                   0                                         sleep late
# 1                   0  remains the same sleeping routine with or with...
# 2                   1                                 I don't drink.. :)
# 3                   1                                         sleep late
# 4                   0  remains the same sleeping routine with or with...
#
#                               Coffee_sleepingPattern  \
# 0                                         sleep late
# 1                                         sleep late
# 2  remains the same sleeping routine with or with...
# 3                                         sleep late
# 4  remains the same sleeping routine with or with...
#
#                         EnergyDrinks_sleepingPattern  \
# 0  remains the same sleeping routine with or with...
# 1                                         sleep late
# 2  remains the same sleeping routine with or with...
# 3                                 I don't drink.. :)
# 4  remains the same sleeping routine with or with...
#
#                           SoftDrinks_sleepingPattern  \
# 0  remains the same sleeping routine with or with...
# 1  remains the same sleeping routine with or with...
# 2  remains the same sleeping routine with or with...
# 3                                 I don't drink.. :)
# 4  remains the same sleeping routine with or with...
#
#                                 Milk_sleepingPattern  \
# 0  remains the same sleeping routine with or with...
# 1  remains the same sleeping routine with or with...
# 2  remains the same sleeping routine with or with...
# 3  remains the same sleeping routine with or with...
# 4              feels sleepy...sleep early than usual
#
#                               Juices_sleepingPattern SleepingSchedule  \
# 0  remains the same sleeping routine with or with...          7-8 hrs
# 1  remains the same sleeping routine with or with...          7-8 hrs
# 2  remains the same sleeping routine with or with...          5-6 hrs
# 3  remains the same sleeping routine with or with...     above 10 hrs
# 4  remains the same sleeping routine with or with...          7-8 hrs
#
#   BeveragesAfftectingSleep
# 0                      Yes
# 1                      Yes
# 2                       No
# 3                       No
# 4                       No

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          72 non-null     object
#  1   Age                           72 non-null     object
#  2   TEA_consumption               72 non-null     int64
#  3   Coffee_consumption            72 non-null     int64
#  4   EnergyDrinks_consumption      72 non-null     int64
#  5   SoftDrinks_consumption        72 non-null     int64
#  6   Milk_consumption              72 non-null     int64
#  7   Juices_consumption            72 non-null     int64
#  8   TEA_sleepingPattern           72 non-null     object
#  9   Coffee_sleepingPattern        72 non-null     object
#  10  EnergyDrinks_sleepingPattern  72 non-null     object
#  11  SoftDrinks_sleepingPattern    72 non-null     object
#  12  Milk_sleepingPattern          72 non-null     object
#  13  Juices_sleepingPattern        72 non-null     object
#  14  SleepingSchedule              72 non-null     object
#  15  BeveragesAfftectingSleep      72 non-null     object
# dtypes: int64(6), object(10)
# memory usage: 9.1+ KB

# %%
# Encode the columns using LabelEncoder
for columns in data.columns:
    labelencoder = LabelEncoder()
    if columns not in ['Name'] and data[columns].dtypes == 'O':
        data[columns] = labelencoder.fit_transform(data[columns])
        print(columns)
        print(labelencoder.classes_)
        print("\n")
# Out:
# Age
# ['20 - 30 yrs' '40 -50 yrs' 'below 20 yrs']
#
#
# TEA_sleepingPattern
# ["I don't drink.. :)" 'feels sleepy...sleep early than usual'
#  'remains the same sleeping routine with or without drinking' 'sleep late']
#
#
# Coffee_sleepingPattern
# ["I don't drink.. :)" 'feels sleepy...sleep early than usual'
#  'remains the same sleeping routine with or without drinking' 'sleep late']
#
#
# EnergyDrinks_sleepingPattern
# ["I don't drink.. :)" 'feels sleepy...sleep early than usual'
#  'remains the same sleeping routine with or without drinking' 'sleep late']
#
#
# SoftDrinks_sleepingPattern
# ["I don't drink.. :)" 'feels sleepy...sleep early than usual'
#  'remains the same sleeping routine with or without drinking' 'sleep late']
#
#
# Milk_sleepingPattern
# ["I don't drink.. :)" 'feels sleepy...sleep early than usual'
#  'remains the same sleeping routine with or without drinking' 'sleep late']
#
#
# Juices_sleepingPattern
# ["I don't drink.. :)" 'feels sleepy...sleep early than usual'
#  'remains the same sleeping routine with or without drinking' 'sleep late']
#
#
# SleepingSchedule
# ['2-4 hrs' '5-6 hrs' '7-8 hrs' '9-10 hrs' 'above 10 hrs']
#
#
# BeveragesAfftectingSleep
# ['No' 'Yes']

# %%
data.head()
# Out:
#                Name  Age  TEA_consumption  Coffee_consumption  \
# 0           Yagnesh    2                1                   0
# 1  Omikumar Makadia    0                2                   3
# 2      Devyash Shah    0                0                   2
# 3          Om Shah     2                2                   2
# 4      Sarthak dave    0                3                   3
#
#    EnergyDrinks_consumption  SoftDrinks_consumption  Milk_consumption  \
# 0                         0                       0                 1
# 1                         0                       1                 1
# 2                         0                       1                 0
# 3                         0                       0                 1
# 4                         1                       1                 1
#
#    Juices_consumption  TEA_sleepingPattern  Coffee_sleepingPattern  \
# 0                   0                    3                       3
# 1                   0                    2                       3
# 2                   1                    0                       2
# 3                   1                    3                       3
# 4                   0                    2                       2
#
#    EnergyDrinks_sleepingPattern  SoftDrinks_sleepingPattern  \
# 0                             2                           2
# 1                             3                           2
# 2                             2                           2
# 3                             0                           0
# 4                             2                           2
#
#    Milk_sleepingPattern  Juices_sleepingPattern  SleepingSchedule  \
# 0                     2                       2                 2
# 1                     2                       2                 2
# 2                     2                       2                 1
# 3                     2                       2                 4
# 4                     1                       2                 2
#
#    BeveragesAfftectingSleep
# 0                         1
# 1                         1
# 2                         0
# 3                         0
# 4                         0

# %%
data.to_csv("DataEncoding.csv")
data = data.iloc[:,1:]

# %%
data.head()
# Out:
#    Age  TEA_consumption  Coffee_consumption  EnergyDrinks_consumption  \
# 0    2                1                   0                         0
# 1    0                2                   3                         0
# 2    0                0                   2                         0
# 3    2                2                   2                         0
# 4    0                3                   3                         1
#
#    SoftDrinks_consumption  Milk_consumption  Juices_consumption  \
# 0                       0                 1                   0
# 1                       1                 1                   0
# 2                       1                 0                   1
# 3                       0                 1                   1
# 4                       1                 1                   0
#
#    TEA_sleepingPattern  Coffee_sleepingPattern  EnergyDrinks_sleepingPattern  \
# 0                    3                       3                             2
# 1                    2                       3                             3
# 2                    0                       2                             2
# 3                    3                       3                             0
# 4                    2                       2                             2
#
#    SoftDrinks_sleepingPattern  Milk_sleepingPattern  Juices_sleepingPattern  \
# 0                           2                     2                       2
# 1                           2                     2                       2
# 2                           2                     2                       2
# 3                           0                     2                       2
# 4                           2                     1                       2
#
#    SleepingSchedule  BeveragesAfftectingSleep
# 0                 2                         1
# 1                 2                         1
# 2                 1                         0
# 3                 4                         0
# 4                 2                         0
